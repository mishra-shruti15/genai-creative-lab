# %%
"""
Task 5: LLMs Intro
Implement different types of Runnables in LangChain:
- invoke()
- batch()
- stream()
"""

from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate


# Create LLM
llm = ChatOllama(
    model="llama3",
    temperature=0
)

# Create Prompt Template
prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a good AI assistant."),
        ("human","{input}")
    ]
)

# Create Runnable (Prompt -> LLM)
chain = prompt | llm

# INVOKE :  Single input -> single output
def run_invoke() -> None:
    print("\n================ INVOKE =================")

    response = chain.invoke(
        {"input": "Tell me a joke in one sentence."}
    )
    # print(f"\nResponse {input}: ")
    print(response.content)


# BATCH: Multiple inputs -> multiple outputs
def run_batch() -> None:
    print("\n================ BATCH =================")

    responses = chain.batch(
        [
            {"input":"What is LangChain?"},
            {"input":"What is a Runnable in Langchain?"},
            {"input":"Why are LLMs useful??"}
        ]
    )

    for index,response in enumerate(responses,start = 1):
        print(f"\nResponse {index}: ")
        print(response.content)


#STREAM : token-by-token output

def run_stream() -> None:
    print("\n================ STREAM =================")
    for chunk in chain.stream(
        {"input":"Explain RAG in simple terms."}
    ):
        text = getattr(chunk, "content", "")
        if text:
            print(text, end="", flush = True)
    
    print("\n")

# Main Execution
if __name__ == "__main__":
    run_invoke()
    run_batch()
    run_stream()
# Out:
# ================ INVOKE =================
# Why did the computer go to therapy? Because it had a little glitch!
#
# ================ BATCH =================
#
# Response 1:
# LangChain is an open-source, cloud-based language model that enables users to generate text based on a given prompt or topic. It's designed to be highly customizable and flexible, allowing developers and researchers to fine-tune the model for specific use cases.
#
# LangChain is built on top of the popular transformer architecture, which has been shown to be effective in natural language processing tasks such as language translation, question answering, and text generation. The model is trained on a massive dataset of text from various sources, including books, articles, and websites.
#
# Some key features of LangChain include:
#
# 1. Prompt-based generation: Users can input a prompt or topic, and the model will generate text that's relevant to the given context.
# 2. Customizable output: Developers can adjust parameters such as the length of the generated text, the tone, and the level of formality to suit their specific needs.
# 3. Multilingual support: LangChain supports multiple languages, allowing users to generate text in different languages.
# 4. Integration with other AI models: LangChain can be integrated with other AI models, such as chatbots, virtual assistants, or content generation platforms.
#
# LangChain has a wide range of potential applications, including:
#
# 1. Content creation: LangChain can be used to generate articles, blog posts, social media updates, and other types of content.
# 2. Chatbots and virtual assistants: The model can be integrated with chatbots and virtual assistants to provide more personalized and engaging interactions.
# 3. Language translation: LangChain can be used for machine translation tasks, such as translating text from one language to another.
# 4. Research and development: Researchers and developers can use LangChain as a foundation for building new AI models or testing hypotheses.
#
# Overall, LangChain is an exciting technology that has the potential to revolutionize the way we interact with language and generate content.
#
# Response 2:
# In LangChain, a Runnable is a type of component that represents a specific task or function that can be executed within the language model's workflow.
#
# A Runnable is essentially a self-contained piece of code that performs a particular action, such as:
#
# 1. Processing natural language input
# 2. Generating text output
# 3. Performing mathematical calculations
# 4. Interacting with external APIs or services
#
# Runnables are designed to be modular and reusable, allowing developers to create complex workflows by combining multiple Runnables in a specific order.
#
# In LangChain, you can define your own custom Runnables using Python code, which can then be integrated into the language model's workflow. This enables you to automate various tasks, such as:
#
# * Text classification
# * Sentiment analysis
# * Named entity recognition
# * Summarization
# * Translation
#
# By leveraging Runnables, developers can create sophisticated language-based applications that can perform a wide range of tasks, from simple text processing to complex decision-making.
#
# Would you like to know more about how to define and use Runnables in LangChain?
#
# Response 3:
# Large Language Models (LLMs) like myself are incredibly useful for several reasons:
#
# 1. **Natural Language Processing**: LLMs can process and understand natural language, allowing us to analyze, generate, and manipulate text in a way that's similar to human-like intelligence.
# 2. **Information Retrieval**: We can quickly scan vast amounts of text data, identify relevant information, and provide accurate answers to questions or summarize complex topics.
# 3. **Text Generation**: LLMs can create original text based on input prompts, making us useful for tasks like writing articles, composing emails, or generating chatbot responses.
# 4. **Language Translation**: We can translate text from one language to another, facilitating communication across linguistic and cultural boundaries.
# 5. **Sentiment Analysis**: LLMs can analyze the emotional tone of text, helping us understand sentiment, detect biases, and identify potential issues.
# 6. **Conversational AI**: By understanding context and responding accordingly, we can engage in natural-sounding conversations with humans, making us suitable for applications like customer service chatbots or voice assistants.
# 7. **Research and Discovery**: LLMs can assist researchers by providing insights into large datasets, identifying patterns, and generating hypotheses.
# 8. **Content Creation**: We can help generate ideas, outlines, and even entire articles or stories, freeing up human writers to focus on higher-level creative tasks.
# 9. **Error Detection**: LLMs can detect grammatical errors, inconsistencies, and inaccuracies in text, making us useful for proofreading and editing purposes.
# 10. **Learning and Education**: By providing personalized learning experiences, we can help students learn new languages, improve their writing skills, or explore complex topics in an engaging way.
#
# These are just a few examples of the many ways LLMs like myself can be useful. As AI technology continues to evolve, I'm excited to see how we'll continue to make a positive impact on various industries and aspects of life!
#
# ================ STREAM =================
# RAG stands for Red, Amber, Green. It's a simple way to categorize or prioritize things based on their level of importance or urgency.
#
# Here's what each color typically means:
#
# * **Red** (R): High priority, urgent, or critical. This is something that needs attention right away.
# * **Amber** (A): Medium priority, important but not urgent. This is something that should be done soon, but there's some flexibility in the timeline.
# * **Green** (G): Low priority, routine, or non-urgent. This is something that can be done at a leisurely pace.
#
# RAG is often used in project management, customer service, and other areas where tasks need to be prioritized. It helps teams quickly identify what needs attention first and allocate resources accordingly.
