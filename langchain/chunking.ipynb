# %%
pip install langchain langchain-core langchain-community langchain-ollama langgraph
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (1.2.10)
# Requirement already satisfied: langchain-core in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (1.2.13)
# Requirement already satisfied: langchain-community in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (0.4.1)
# Requirement already satisfied: langchain-ollama in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (1.0.1)
# Requirement already satisfied: langgraph in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (1.0.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\development\anaconda3\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\development\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langchain-core) (0.7.3)
# Requirement already satisfied: packaging>=23.2.0 in c:\development\anaconda3\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\development\anaconda3\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\development\anaconda3\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\development\anaconda3\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langchain-core) (0.14.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langgraph) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langgraph) (0.3.6)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\development\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\development\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\development\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\development\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\development\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.24.0)
# Requirement already satisfied: anyio in c:\development\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.10.0)
# Requirement already satisfied: certifi in c:\development\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\development\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\development\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\development\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\development\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\development\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\development\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\development\anaconda3\lib\site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\development\anaconda3\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\development\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\development\anaconda3\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\development\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\development\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\development\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\development\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\development\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\development\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\development\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\development\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\development\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\development\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\development\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\development\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: ollama<1.0.0,>=0.6.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from langchain-ollama) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in c:\development\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# The system cannot find the path specified.

# %%
pip install tiktoken faiss-cpu sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tiktoken in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (0.12.0)
# Requirement already satisfied: faiss-cpu in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (1.13.2)
# Requirement already satisfied: sentence-transformers in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (5.2.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\development\anaconda3\lib\site-packages (from tiktoken) (2025.9.1)
# Requirement already satisfied: requests>=2.26.0 in c:\development\anaconda3\lib\site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\development\anaconda3\lib\site-packages (from faiss-cpu) (2.3.5)
# Requirement already satisfied: packaging in c:\development\anaconda3\lib\site-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from sentence-transformers) (5.1.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: scikit-learn in c:\development\anaconda3\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\development\anaconda3\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\development\anaconda3\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in c:\development\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\development\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer-slim in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.23.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock in c:\development\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\development\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\development\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: shellingham in c:\development\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: anyio in c:\development\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\development\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\development\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\development\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\development\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\development\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\development\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\development\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\development\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\development\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\development\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\development\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\development\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\development\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\development\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\development\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\development\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: typer>=0.23.1 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.23.1)
# Requirement already satisfied: click>=8.0.0 in c:\development\anaconda3\lib\site-packages (from typer>=0.23.1->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.2.1)
# Requirement already satisfied: rich>=10.11.0 in c:\development\anaconda3\lib\site-packages (from typer>=0.23.1->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\shruti mishra\appdata\roaming\python\python313\site-packages (from typer>=0.23.1->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\development\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\development\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\development\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.1->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# The system cannot find the path specified.

# %%
"""
Task 9: Chunking
Implement different chunking strategies using LangChain

"""

from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import (
    CharacterTextSplitter,
    RecursiveCharacterTextSplitter,
    TokenTextSplitter
)


# =================================================
# LOAD DOCUMENT
# =================================================
def load_document():
    loader = TextLoader("sample.txt")
    documents = loader.load()
    return documents



# =================================================
#  CHARACTER-BASED CHUNKING
# =================================================
def character_chunking(documents):
    print("\n========== CHARACTER CHUNKING ==========")

    splitter = CharacterTextSplitter(
        chunk_size=100,
        chunk_overlap=20
    )

    chunks = splitter.split_documents(documents)

    for i, chunk in enumerate(chunks, start=1):
        print(f"\nChunk {i}:\n{chunk.page_content}")


# =================================================
# RECURSIVE CHARACTER CHUNKING 
# =================================================
def recursive_chunking(documents):
    print("\n========== RECURSIVE CHUNKING ==========")

    splitter = RecursiveCharacterTextSplitter(
        chunk_size=100,
        chunk_overlap=20
    )

    chunks = splitter.split_documents(documents)

    for i, chunk in enumerate(chunks, start=1):
        print(f"\nChunk {i}:\n{chunk.page_content}")


# =================================================
# TOKEN-BASED CHUNKING
# =================================================
def token_chunking(documents):
    print("\n========== TOKEN CHUNKING ==========")

    splitter = TokenTextSplitter(
        chunk_size=30,
        chunk_overlap=5
    )

    chunks = splitter.split_documents(documents)

    for i, chunk in enumerate(chunks, start=1):
        print(f"\nChunk {i}:\n{chunk.page_content}")


# -------------------------------------------------
# Main Execution
# -------------------------------------------------
if __name__ == "__main__":
    docs = load_document()
    character_chunking(docs)
    recursive_chunking(docs)
    token_chunking(docs)
# Out:
# ========== CHARACTER CHUNKING ==========
#
# Chunk 1:
# LangChain is a framework for building applications using large language models.
# It helps with chaining prompts, managing memory, tools, and agents.
# It is widely used for building RAG and agent-based systems.
#
# ========== RECURSIVE CHUNKING ==========
#
# Chunk 1:
# LangChain is a framework for building applications using large language models.
#
# Chunk 2:
# It helps with chaining prompts, managing memory, tools, and agents.
#
# Chunk 3:
# It is widely used for building RAG and agent-based systems.
#
# ========== TOKEN CHUNKING ==========
#
# Chunk 1:
# LangChain is a framework for building applications using large language models.
# It helps with chaining prompts, managing memory, tools, and agents.
#
# Chunk 2:
#  tools, and agents.
# It is widely used for building RAG and agent-based systems.
